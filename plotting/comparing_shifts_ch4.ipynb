# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
### This notebook compares transforms with their shifted versions (shifted s.t. r-> (r-r_displacement) )
# N_train = N_test = 1000, a = 4.5, Emax = 400

Path = '/home/ach/radial-physics_new/radial-physics/output/shifted_old/ch4'

for i in range(1,9):
    
    # displacement_gold = [] #Define/reset lists + open data
    # rmse_gold = []
    # data_gold = open(Path+f'/Data_TR{i}_gold','r')
    # displacement_qm9 = []
    # rmse_qm9 = []
    # data_qm9 = open(Path+f'/Data_TR{i}_qm9','r')
    displacement_ch4 = []
    factor_ch4 = []
    rmse_ch4 = []
    data_ch4 = open(Path+f'/Data_TR{i}_random-ch4-10k','r')
    # for row in data_qm9: #QM9
    #     row = row.split(' ')
    #     displacement_qm9.append(float(row[1]))
    #     rmse_qm9.append(float(row[2]))
    
    # for row in data_gold: #Gold
    #     row = row.split(' ')
    #     displacement_gold.append(float(row[1]))
    #     rmse_gold.append(float(row[2]))
    
    for row in data_ch4: #Methane
        row = row.split(' ')
        factor_ch4.append(float(row[0]))
        displacement_ch4.append(float(row[1]))
        rmse_ch4.append(float(row[2]))
    
    # plt.plot(displacement_gold, rmse_gold , '.', label=f"Gold")
    # plt.plot(displacement_qm9, rmse_qm9 , '.', label="QM9")
    # plt.plot(displacement_ch4, rmse_ch4 , '.', label="CH4")
    # plt.yscale('log')

    # plt.xlabel('Displacement')
    # plt.ylabel('MSE')
    # plt.title(f"Transform {i}")
    # plt.legend()
    # plt.show()

    # fig, ax1 = plt.subplots()
    
    # ax1.set_ylabel('RMSE QM9, CH4')  # we already handled the x-label with ax1
    # ax1.plot(displacement_qm9, rmse_qm9 , '.', label="QM9")
    # ax1.plot(displacement_ch4, rmse_ch4 , '.', label="CH4")
    # ax1.tick_params(axis='y')

    # ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

    # ax2.set_xlabel('Displacement')
    # ax2.set_ylabel('RMSE Gold')
    # ax2.plot(displacement_gold, rmse_gold , '.', label=f"Gold", color = '0.75')
    # ax2.tick_params(axis='y')

    # fig.tight_layout()
    # plt.title(f"Transform {i}")
    # # plt.figlegend()
    # fig.legend(bbox_to_anchor=(1.15, 1.1), ncol=5)
    no_datapoints = len(displacement_ch4)
    print(no_datapoints)
    for j in range(int(no_datapoints/5)):
        plt.plot(displacement_ch4[(5*j):(5+5*j)], rmse_ch4[(5*j):(5+5*j)] , "-o", label=f"Factor = {factor_ch4[(5*j)]}")
        # plt.plot(displacement_ch4[5:10], rmse_ch4[5:10], "r-o", label=f"Factor = {factor_ch4[5]}")
        # plt.plot(displacement_ch4[10:15], rmse_ch4[10:15], "g-o", label=f"Factor = {factor_ch4[10]}")
    plt.title(f"Transform {i} for CH4")
    plt.xlabel("Displacement [Å]")
    plt.ylabel("RMSE [kcal/mol]")

    plt.legend()

    plt.show()

    ### one plot with all minima:
# Out:
# 35
# 55
# 35
# 40
# 35
# 12
# 35
# 12
